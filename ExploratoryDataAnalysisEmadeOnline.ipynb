# %%
#Libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#ignore the warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#call the variables
df = pd.read_csv('online.csv')
df
# Out:
#      Unnamed: 0 order_status   Monthly Income  latitude Marital Status  \
# 0             0          Yes   25001 to 50000   13.0262        Married
# 1             1          Yes        No Income   12.9770         Single
# 2             2          Yes        No Income   12.9770         Single
# 3             3          Yes        No Income   13.0019         Single
# 4             4          Yes  More than 50000   13.0626        Married
# ..          ...          ...              ...       ...            ...
# 383         383          Yes        No Income   12.9883         Single
# 384         384          Yes        No Income   13.0223         Single
# 385         385          Yes   10001 to 25000   12.9850         Single
# 386         386          Yes   10001 to 25000   12.9698         Single
# 387         387          Yes        No Income   12.9770         Single
#
#      Gender employment_status  Family size   Reviews  Pin code   Age  \
# ...

# %%
#Show Top 5 records
df.head()
# Out:
#    Unnamed: 0 order_status   Monthly Income  latitude Marital Status  Gender  \
# 0           0          Yes   25001 to 50000   13.0262        Married    Male
# 1           1          Yes        No Income   12.9770         Single    Male
# 2           2          Yes        No Income   12.9770         Single  Female
# 3           3          Yes        No Income   13.0019         Single  Female
# 4           4          Yes  More than 50000   13.0626        Married    Male
#
#   employment_status  Family size   Reviews  Pin code   Age  longitude  \
# 0          Employee          5.0  Positive    560045  28.0    77.6200
# 1           Student          NaN  Positive    560009   NaN    77.5773
# 2           Student          NaN  Positive    560009   NaN    77.5773
# 3           Student          NaN  Positive    560003   NaN    77.5713
# 4    Self Employeed          NaN  Positive    560015   NaN    77.5284
#
#   Educational Qualifications Unnamed: 13   9           #@%
# ...

# %%
#Show bottom 10 records
df.tail(10)
# Out:
#      Unnamed: 0 order_status   Monthly Income  latitude Marital Status  \
# 378         378           No   10001 to 25000   12.9706        Married
# 379         379          Yes        No Income   12.8845         Single
# 380         380          Yes   25001 to 50000   12.9766         Single
# 381         381           No  More than 50000   13.0503         Single
# 382         382           No  More than 50000   12.9337         Single
# 383         383          Yes        No Income   12.9883         Single
# 384         384          Yes        No Income   13.0223         Single
# 385         385          Yes   10001 to 25000   12.9850         Single
# 386         386          Yes   10001 to 25000   12.9698         Single
# 387         387          Yes        No Income   12.9770         Single
#
#      Gender employment_status  Family size    Reviews  Pin code   Age  \
# 378  Female    Self Employeed          5.0  Negative     560075  26.0
# ...

# %%
#Select a specific column
df['Gender']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4        Male
#         ...
# 383    Female
# 384      Male
# 385    Female
# 386    Female
# 387      Male
# Name: Gender, Length: 388, dtype: object

# %%
#Select a speciic column alt
df.Gender
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4        Male
#         ...
# 383    Female
# 384      Male
# 385    Female
# 386    Female
# 387      Male
# Name: Gender, Length: 388, dtype: object

# %%
#filter record for Gender = Female
df[df['Gender'] == 'Female']
# Out:
#      Unnamed: 0 order_status   Monthly Income  latitude Marital Status  \
# 2             2          Yes        No Income   12.9770         Single
# 3             3          Yes        No Income   13.0019         Single
# 5             5          Yes        No Income   12.9369         Single
# 7             7           No   25001 to 50000   13.0103         Single
# 10           10          Yes  More than 50000   12.9299        Married
# ..          ...          ...              ...       ...            ...
# 377         377           No   25001 to 50000   12.9783        Married
# 378         378           No   10001 to 25000   12.9706        Married
# 383         383          Yes        No Income   12.9883         Single
# 385         385          Yes   10001 to 25000   12.9850         Single
# 386         386          Yes   10001 to 25000   12.9698         Single
#
#      Gender employment_status  Family size    Reviews  Pin code   Age  \
# ...

# %%
#filter record for Gender = Male
df[df['Gender'] == 'Male']
# Out:
#      Unnamed: 0 order_status   Monthly Income  latitude Marital Status Gender  \
# 0             0          Yes   25001 to 50000   13.0262        Married   Male
# 1             1          Yes        No Income   12.9770         Single   Male
# 4             4          Yes  More than 50000   13.0626        Married   Male
# 6             6          Yes  More than 50000   12.9442        Married   Male
# 8             8          Yes   10001 to 25000   12.9820        Married   Male
# ..          ...          ...              ...       ...            ...    ...
# 380         380          Yes   25001 to 50000   12.9766         Single   Male
# 381         381           No  More than 50000   13.0503         Single   Male
# 382         382           No  More than 50000   12.9337         Single   Male
# 384         384          Yes        No Income   13.0223         Single   Male
# 387         387          Yes        No Income   12.9770         Single   Male
#
# ...

# %%
#show employment when self employeed
df[df['employment_status'] == 'Self Employeed']
# Out:
#      Unnamed: 0 order_status   Monthly Income  latitude     Marital Status  \
# 4             4          Yes  More than 50000   13.0626            Married
# 7             7           No   25001 to 50000   13.0103             Single
# 8             8          Yes   10001 to 25000   12.9820            Married
# 20           20           No  More than 50000   13.0809            Married
# 21           21           No   10001 to 25000   12.9706            Married
# 22           22          Yes   10001 to 25000   12.9438             Single
# 26           26          Yes   10001 to 25000   12.9820            Married
# 34           34          Yes   10001 to 25000   13.0206             Single
# 49           49           No   25001 to 50000   12.9217            Married
# 60           60          Yes   25001 to 50000   13.0078            Married
# 63           63          Yes  More than 50000   12.8845             Single
# ...

# %%
#show marital status when single
df[df['Marital Status'] == 'Single']
# Out:
#      Unnamed: 0 order_status  Monthly Income  latitude Marital Status  Gender  \
# 1             1          Yes       No Income   12.9770         Single    Male
# 2             2          Yes       No Income   12.9770         Single  Female
# 3             3          Yes       No Income   13.0019         Single  Female
# 5             5          Yes       No Income   12.9369         Single  Female
# 7             7           No  25001 to 50000   13.0103         Single  Female
# ..          ...          ...             ...       ...            ...     ...
# 383         383          Yes       No Income   12.9883         Single  Female
# 384         384          Yes       No Income   13.0223         Single    Male
# 385         385          Yes  10001 to 25000   12.9850         Single  Female
# 386         386          Yes  10001 to 25000   12.9698         Single  Female
# 387         387          Yes       No Income   12.9770         Single    Male
#
# ...

# %%
#show marital status and gender where single and female
MaritalStatusandGender=df[(df['Marital Status'] == 'Single') & (df['Gender'] == 'Female')]
MaritalStatusandGender
# Out:
#      Unnamed: 0 order_status  Monthly Income  latitude Marital Status  Gender  \
# 2             2          Yes       No Income   12.9770         Single  Female
# 3             3          Yes       No Income   13.0019         Single  Female
# 5             5          Yes       No Income   12.9369         Single  Female
# 7             7           No  25001 to 50000   13.0103         Single  Female
# 17           17          Yes       No Income   12.9343         Single  Female
# ..          ...          ...             ...       ...            ...     ...
# 364         364          Yes       No Income   13.0487         Single  Female
# 373         373          Yes       No Income   12.9119         Single  Female
# 383         383          Yes       No Income   12.9883         Single  Female
# 385         385          Yes  10001 to 25000   12.9850         Single  Female
# 386         386          Yes  10001 to 25000   12.9698         Single  Female
#
# ...

# %%
#How to check for null
df.isna().sum()
# Out:
# Unnamed: 0                      0
# order_status                    0
# Monthly Income                  0
# latitude                        0
# Marital Status                  0
# Gender                          0
# employment_status               0
# Family size                    19
# Reviews                         0
# Pin code                        0
# Age                            19
# longitude                       0
# Educational Qualifications      0
# Unnamed: 13                     0
# 9                             388
# #@%                           382
# dtype: int64

# %%
#How to drop null in Family size
df=df.dropna(subset = ['Family size'])
df
# Out:
#      Unnamed: 0 order_status   Monthly Income  latitude Marital Status  \
# 0             0          Yes   25001 to 50000   13.0262        Married
# 5             5          Yes        No Income   12.9369         Single
# 6             6          Yes  More than 50000   12.9442        Married
# 7             7           No   25001 to 50000   13.0103         Single
# 8             8          Yes   10001 to 25000   12.9820        Married
# ..          ...          ...              ...       ...            ...
# 383         383          Yes        No Income   12.9883         Single
# 384         384          Yes        No Income   13.0223         Single
# 385         385          Yes   10001 to 25000   12.9850         Single
# 386         386          Yes   10001 to 25000   12.9698         Single
# 387         387          Yes        No Income   12.9770         Single
#
#      Gender employment_status  Family size    Reviews  Pin code   Age  \
# ...

# %%
#How to check for null to confirm
df.isna().sum()
# Out:
# Unnamed: 0                      0
# order_status                    0
# Monthly Income                  0
# latitude                        0
# Marital Status                  0
# Gender                          0
# employment_status               0
# Family size                     0
# Reviews                         0
# Pin code                        0
# Age                             0
# longitude                       0
# Educational Qualifications      0
# Unnamed: 13                     0
# 9                             369
# #@%                           367
# dtype: int64

# %%
#See all the columns
df=pd.DataFrame(df)
df.head()
columnlist=list(df.columns)
columnlist
# Out:
# ['Unnamed: 0',
#  'order_status',
#  'Monthly Income',
#  'latitude',
#  'Marital Status',
#  'Gender',
#  'employment_status',
#  'Family size',
#  'Reviews',
#  'Pin code',
#  'Age',
#  'longitude',
#  'Educational Qualifications',
#  'Unnamed: 13',
#  '9',
#  '#@%']

# %%
#How to drop column
df.drop(columns = '#@%' ,inplace = True)
df.head()
# Out:
#    Unnamed: 0 order_status   Monthly Income  latitude Marital Status  Gender  \
# 0           0          Yes   25001 to 50000   13.0262        Married    Male
# 1           1          Yes        No Income   12.9770         Single    Male
# 2           2          Yes        No Income   12.9770         Single  Female
# 3           3          Yes        No Income   13.0019         Single  Female
# 4           4          Yes  More than 50000   13.0626        Married    Male
#
#   employment_status  Family size   Reviews  Pin code   Age  longitude  \
# 0          Employee          5.0  Positive    560045  28.0    77.6200
# 1           Student          NaN  Positive    560009   NaN    77.5773
# 2           Student          NaN  Positive    560009   NaN    77.5773
# 3           Student          NaN  Positive    560003   NaN    77.5713
# 4    Self Employeed          NaN  Positive    560015   NaN    77.5284
#
#   Educational Qualifications Unnamed: 13   9
# ...

# %%
#How to check for null to confirm
df.isna().sum()
# Out:
# Unnamed: 0                      0
# order_status                    0
# Monthly Income                  0
# latitude                        0
# Marital Status                  0
# Gender                          0
# employment_status               0
# Family size                    19
# Reviews                         0
# Pin code                        0
# Age                            19
# longitude                       0
# Educational Qualifications      0
# Unnamed: 13                     0
# 9                             388
# dtype: int64

# %%
#How to read other files
pd.read_csv('C:\\Users\\WORK-PC\\Documents\\ETL Training\\Inbound\\Report\\online.csv')
# Out:
#      Unnamed: 0 order_status   Monthly Income  latitude Marital Status  \
# 0             0          Yes   25001 to 50000   13.0262        Married
# 1             1          Yes        No Income   12.9770         Single
# 2             2          Yes        No Income   12.9770         Single
# 3             3          Yes        No Income   13.0019         Single
# 4             4          Yes  More than 50000   13.0626        Married
# ..          ...          ...              ...       ...            ...
# 383         383          Yes        No Income   12.9883         Single
# 384         384          Yes        No Income   13.0223         Single
# 385         385          Yes   10001 to 25000   12.9850         Single
# 386         386          Yes   10001 to 25000   12.9698         Single
# 387         387          Yes        No Income   12.9770         Single
#
#      Gender employment_status  Family size   Reviews  Pin code   Age  \
# ...

# %%
# clean, Load, read data into sql server ref wk 16 xtraclass ending
