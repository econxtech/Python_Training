# %%
print( "Hello Team" )
# Out:
# Hello Team

# %%
#£variables
Jerry = "Bye Team"
print (Jerry)
# Out:
# Bye Team

# %%
print (Jerry.upper())
# Out:
# BYE TEAM

# %%
#variables
firstName = "Tom"
lastName = "Jerry"
fullName = firstName + " " + lastName
print(fullName)
# Out:
# Tom Jerry

# %%
# add a new line
print("languages:\n\tpython\tjava\n\tgo")
# Out:
# languages:
# 	python	java
# 	go

# %%
# add a new line to name
firstname = "Tom"
lastname = "Jerry"
fullname = f"{firstname}{lastname}"
print(f"fullname: \n\t{firstname}\n\t{lastname}")
# Out:
# fullname:
# 	Tom
# 	Jerry

# %%
# Data Type:
# Numbers
2+3
# Out:
# 5

# %%
5+8
# Out:
# 13

# %%
(2+3)*4
# Out:
# 20

# %%
3**2
# Out:
# 9

# %%
3**4
# Out:
# 81

# %%
# float -- its like decimal
0.1 + 0.1
# Out:
# 0.2

# %%
2*0.2
# Out:
# 0.4

# %%
# age -- concatenate (join) string and integer
age = 83
message = "happy" + " " + str(age) + "rd birthday, prof!"
#message = "happy " + str(age) + "rd birthday, prof!"
print(message.upper())
# Out:
# HAPPY 83RD BIRTHDAY, PROF!
